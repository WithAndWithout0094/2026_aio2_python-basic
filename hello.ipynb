# %%
# 변수 선언
name = "영석"

# 나이 입력받기
age = int(input("나이를 입력하세요"))
"""
위 input에는 print가 이미 포함이 되어있기 때문에 
input(print("내용"))로 하지않고 input("내용")으로만
작성하면 된다.
"""

# 결과 출력
print(f"이름: {name}, 나이: {age}")
# Out:
# 이름: 영석, 나이: 34

# %%
import sys
print("Hello, Python!")
print("Python 버전:", sys.version)
print("실행 파일:", sys.executable)
# Out:
# Hello, Python!
# Python 버전: 3.12.10 (tags/v3.12.10:0cc8128, Apr  8 2025, 12:21:36) [MSC v.1943 64 bit (AMD64)]
# 실행 파일: c:\study\python-basic\.venv\Scripts\python.exe
