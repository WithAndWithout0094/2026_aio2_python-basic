# %%
#
print("# 하나만 출력합니다")
print("hello python programming...!")
print()

print("여러 개를 출력합니다.")
print(10,20,30,40,50)
print("안녕하세요 저의 이름은 신영석입니다")

1+2
# Out:
# # 하나만 출력합니다
# hello python programming...!
#
# 여러 개를 출력합니다.
# 10 20 30 40 50
# 안녕하세요 저의 이름은 신영석입니다
# 3

# %%
print("Hello python programming...!")
print(52)
print(273)
print()
print(52,273,"hello", "hello")
print("안녕하세요 저의 이름은 신영석입니다")
print("안녕하세요,","저의","이름은","신영석입니다")
print("안녕하세요","저의","이름은","신영석입니다")

print("# 아무것도 출력하지 않습니다")
print("---확인 전용선---")
print()
print()
print("---확인 전용선---")
# Out:
# Hello python programming...!
# 52
# 273
#
# 52 273 hello hello
# 안녕하세요 저의 이름은 신영석입니다
# 안녕하세요, 저의 이름은 신영석입니다
# 안녕하세요 저의 이름은 신영석입니다
# # 아무것도 출력하지 않습니다
# ---확인 전용선---
#
#
# ---확인 전용선---

# %%
print("반갑습니다")
# Out:
# 반갑습니다

# %%
print("Hello!!")
print("안녕히계세요")
# Out:
# Hello!!
# 안녕히계세요
