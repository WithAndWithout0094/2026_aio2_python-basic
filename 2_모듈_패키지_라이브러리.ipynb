# %% [markdown]
# #파이썬 프로그램의 기본 구조 - 실행 가능한 모듈
#
# 변수, 명령어,(내장명령, 라이브러리명령, 내장모듈, 사용자정의 명령-함수)
#
# 알고리즘 구조: 순차, 반복, 조건
# 데이터의 유형: 숫자, 문자, 문자열, 리스트, 딕셔너리, 셋트, 등- 범용
#
# -모듈: *. py(함수들)
# -자료구조: 클래스(변수 + 함수)
#
# -사용자정의 자료구조: 클래스
#     1. 속성: calss/self
#     2. 행위 / 동작: class/static/self
#
# - 아키텍처 제안 매커니즘: 객체지향 프로그래밍 ##중요
#     1. 탭슐화
#     2. 상속
#     3. 다형성

# %% [markdown]
# 패키지
# -모듈의 집합이다.
#
# 머듈의 집합 > 디렉토리(폴더)로 묶어준다
#
# C:\study\python-basic\My_First_Package

# %% [markdown]
# 모듈을 호출하는 코드 : c
# 모듈은 패키지 magic_calc에 포함
# -C:\study\python-basic\My_First_Package\Magic_Calc\basic_ops.py
# -C:\study\python-basic\My_First_Package\Magic_Calc\advanced_ops.py

# %%
#판다스의 데이터프레임 객체 생성
pd.DataFrame(data) #앞에 df를 안붙이면 재활용 불가능.
## pd.DataFrame(data).head() 로 사용은 가능.
## pd.DataFrame(data).head(3) 로 사용은 가능.
# Out:
#     이름  나이  점수
# 0  김철수  25  85
# 1  이영희  28  92
# 2  박민수  22  78
# 3  정수진  31  95
# 4  최영호  27  88
# 5  한미래  24  73
# 6  윤지원  29  91

# %%
df = pd.DataFrame(data)

df.head() #기본은 5개
df.head(3) #3개만
print(df.head(3).mean(numeric_only=True))
print()

print(df['나이'].mean()) #나이 평균
print(df['점수'].mean()) #점수 평균
print()

print(int(df['나이'].mean())) #점수 평균 정수형으로
print(int(df['점수'].mean())) #점수 평균 정수형으로
# Out:
# 나이    25.0
# 점수    85.0
# dtype: float64
#
# 26.571428571428573
# 86.0
#
# 26
# 86

# %%
import pandas as pd

data = {
    '이름': ['김철수', '이영희', '박민수', '정수진', '최영호', '한미래', '윤지원'],
    '나이': [25, 28, 22, 31, 27, 24, 29],
    '점수': [85, 92, 78, 95, 88, 73, 91]
}

# %%
import requests

url = "https://naver.com"

response = requests.get(url)
print("상태 코드:", response.status_code)
print("응답 헤더:")
## 상태코드 200: 정상, 404: 페이지 없음, 500: 서버 오류
# Out:
# 상태 코드: 200

# %% [markdown]
# ## pip install --- 는 터미널에서 설치해야 함.
# 사용할 가상환경 폴더에다가 설치해야 해당 가상환경에서 사용할 수 있음.
#
# 터미널에서 dir를 통해 위치해 있는 폴더를 확인을 하고 설치 진행. pip install 명
# # pypi.org에 일치하는 명칭 찾아다 입력위 [명]에 해당하는 위치에 입력하면 설치 됨.

# %%
# 내장 모듈 사용 연습

import math
print(math.sqrt(36))  # math 모듈의 sqrt 함수 사용

import random
print(random.randint(8, 10)) #(a, b) a=최소, b=최대

import datetime
print(datetime.datetime.now())  # 현재 날짜와 시간 출력
## 프린트(모듈 명. 클래스 명. 매서드 명)
# Out:
# 6.0
# 8

# %% [markdown]
# ## 내장 모듈은 기본 탑재되어있음. 따로 안만들어도 됨.
# ## math = 예시: math.sqrt(16) -> 4.0 (제곱인 샘)
# ## ㄴ수학 함수
#
# ## random = 예시: random.randint(1, 10) -> (1~10 range를 의미함.)
# ## ㄴ랜덤값 생성
#
# ## datetime = 예시: datetime.datetime.now()
# ## ㄴ날짜와 시간 처리
#
# ## os = 예시: os.getcwd()
# ## ㄴ운영체제 관련 기능
#
# ## sys = 예시: sys.version
# ## ㄴ시스템 관련 정보
#
# ## time = 예시: time.sleep(1)
# ## ㄴ시간 관련 기능

# %%
import calc as cc 
## calc 를 앞으로 cc 로 줄여서 사용하겠다는 의미
print(cc.add(55, 22))
print(cc.multiply(55, 22))
# Out:
# 77
# 1210

# %%
from calc import *
print(add(2, 3))
print(multiply(2, 3))
# Out:
# 5
# 6

# %%
from calc import add, multiply
print(add(2, 3))
print(multiply(2, 8))
# Out:
# 5
# 16

# %%
import calc
calc.multiply(2, 3)
print(calc.add(2, 3))
# 프린트 없으면 결과를 확인할 수 없음.지금은 편의 기능으로 가능.
# Out:
# 5

# %%
import calc
calc.add(1, 2)
# 프린트 없으면 결과를 확인할 수 없음.지금은 편의 기능으로 가능.
print(calc.add(1, 2))
print(calc.multiply(5, 2))
# Out:
# 3
